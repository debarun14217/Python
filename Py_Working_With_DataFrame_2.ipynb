# %%
## imported pandas library
import pandas as pd

## reading data file --> 100 Records.csv
df = pd.read_csv("C:\\Users\\DEBARUN\\Documents\\Data Files\\Human_Resource_Data\\100 Records.csv")

## checking first 10 rows
df.head(10)
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
# 1  940761         Ms.     Brenda              S  Robinson      F
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
# 5  499687         Mr.    Patrick              F    Bailey      M
# 6  539712         Ms.      Nancy              T     Baker      F
# 7  380086        Mrs.      Carol              V    Murphy      F
# 8  477616        Hon.    Frances              B     Young      F
# 9  162402        Hon.      Diana              T  Peterson      F
#
#                          E Mail      Father's Name       Mother's Name  \
# 0       lois.walker@hotmail.com      Donald Walker        Helen Walker
# 1     brenda.robinson@gmail.com   Raymond Robinson       Judy Robinson
# ...

# %%
## Checking last 10 rows
df.tail(10)
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 90  185032         Mr.     Eugene              D     Perez      M
# 91  867084         Ms.    Deborah              E     Smith      F
# 92  969964        Hon.     Janice              S    Parker      F
# 93  158666         Ms.    Rebecca              A   Stewart      F
# 94  489424         Dr.    Phillip              F     White      M
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                          E Mail   Father's Name      Mother's Name  \
# 90  eugene.perez@exxonmobil.com     Jimmy Perez         Lois Perez
# 91      deborah.smith@yahoo.com   Richard Smith        Diana Smith
# ...

# %%
## Checking the shape of the data frame
df.shape
# Out:
# (100, 37)

# %%
## store the shape details into a variable
rows, columns = df.shape

## printing row and column numbers by performing data conversion from int to str
print("Total no rows : " + str(rows)) 
print("Total no of columns : " + str(columns))
# Out:
# Total no rows : 100
# Total no of columns : 37

# %%
## To check the name of all the columns in the data frame
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
## Python case sensitive
## If you put columnname "Emp Id" in the place of "Emp ID", it will give you an error
df["Emp ID"]
# Out:
# 0     677509
# 1     940761
# 2     428945
# 3     408351
# 4     193819
# 5     499687
# 6     539712
# 7     380086
# 8     477616
# 9     162402
# 10    231469
# 11    153989
# 12    386158
# 13    301576
# 14    441771
# 15    528509
# 16    912990
# 17    214352
# 18    890290
# 19    622406
# 20    979607
# 21    969580
# 22    426038
# 23    388642
# 24    560455
# 25    477253
# 26    263480
# 27    683826
# 28    474599
# 29    335732
#        ...
# 70    915638
# 71    478003
# 72    951225
# 73    883936
# 74    528673
# 75    765850
# 76    262382
# 77    870820
# 78    806955
# 79    325319
# 80    623253
# 81    225925
# 82    761821
# 83    400173
# 84    802554
# 85    476433
# 86    533952
# 87    623929
# 88    844177
# 89    212893
# 90    185032
# 91    867084
# 92    969964
# 93    158666
# 94    489424
# 95    639892
# 96    704709
# 97    461593
# 98    392491
# 99    495141
# Name: Emp ID, Length: 100, dtype: int64

# %%
## To find the maximum employee id
max_emp_id = df["Emp ID"].max()
print("Highest employee id is : " + str(df["Emp ID"].max()))
print("Highest employee id is : " + str(max_emp_id))

## To find the minimum employee id
min_emp_id = df["Emp ID"].min()
print("Lowest employee id is : " + str(df["Emp ID"].min()))
print("Lowest employee id is : " + str(min_emp_id))
# Out:
# Highest employee id is : 979607
# Highest employee id is : 979607
# Lowest employee id is : 134841
# Lowest employee id is : 134841

# %%
## To print specific column data in different ways
print("specific column data can be checked by using command --> <[data frame name]>.<[column name]>")
df.Gender
# Out:
# specific column data can be checked by using command --> <[data frame name]>.<[column name]>
# 0     F
# 1     F
# 2     M
# 3     F
# 4     M
# 5     M
# 6     F
# 7     F
# 8     F
# 9     F
# 10    M
# 11    M
# 12    F
# 13    M
# 14    F
# 15    F
# 16    M
# 17    F
# 18    F
# 19    M
# 20    F
# 21    M
# 22    F
# 23    F
# 24    F
# 25    F
# 26    M
# 27    M
# 28    F
# 29    F
#      ..
# 70    M
# 71    F
# 72    F
# 73    M
# 74    M
# 75    F
# 76    F
# 77    F
# 78    M
# 79    F
# 80    F
# 81    M
# 82    M
# 83    F
# 84    M
# 85    F
# 86    F
# 87    M
# 88    F
# 89    F
# 90    M
# 91    F
# 92    F
# 93    F
# 94    M
# 95    M
# 96    M
# 97    F
# 98    F
# 99    F
# Name: Gender, Length: 100, dtype: object

# %%
## To print specific column data in different ways
print("specific column data can be checked by using command --> <[data frame name]>['<[column name]>']")
df['Gender']
# Out:
# specific column data can be checked by using command --> <[data frame name]>['<[column name]>']
# or by using command --> <[data frame name]>["<[column name]>"]
# 0     F
# 1     F
# 2     M
# 3     F
# 4     M
# 5     M
# 6     F
# 7     F
# 8     F
# 9     F
# 10    M
# 11    M
# 12    F
# 13    M
# 14    F
# 15    F
# 16    M
# 17    F
# 18    F
# 19    M
# 20    F
# 21    M
# 22    F
# 23    F
# 24    F
# 25    F
# 26    M
# 27    M
# 28    F
# 29    F
#      ..
# 70    M
# 71    F
# 72    F
# 73    M
# 74    M
# 75    F
# 76    F
# 77    F
# 78    M
# 79    F
# 80    F
# 81    M
# 82    M
# 83    F
# 84    M
# 85    F
# 86    F
# 87    M
# 88    F
# 89    F
# 90    M
# 91    F
# 92    F
# 93    F
# 94    M
# 95    M
# 96    M
# 97    F
# 98    F
# 99    F
# Name: Gender, Length: 100, dtype: object

# %%
## To print specific column data in different ways
print('or by using command --> <[data frame name]>["<[column name]>"]')
df["Gender"]
# Out:
# or by using command --> <[data frame name]>["<[column name]>"]
# 0     F
# 1     F
# 2     M
# 3     F
# 4     M
# 5     M
# 6     F
# 7     F
# 8     F
# 9     F
# 10    M
# 11    M
# 12    F
# 13    M
# 14    F
# 15    F
# 16    M
# 17    F
# 18    F
# 19    M
# 20    F
# 21    M
# 22    F
# 23    F
# 24    F
# 25    F
# 26    M
# 27    M
# 28    F
# 29    F
#      ..
# 70    M
# 71    F
# 72    F
# 73    M
# 74    M
# 75    F
# 76    F
# 77    F
# 78    M
# 79    F
# 80    F
# 81    M
# 82    M
# 83    F
# 84    M
# 85    F
# 86    F
# 87    M
# 88    F
# 89    F
# 90    M
# 91    F
# 92    F
# 93    F
# 94    M
# 95    M
# 96    M
# 97    F
# 98    F
# 99    F
# Name: Gender, Length: 100, dtype: object

# %%
## To filter data based of a column based on specific value
print("filtering data where Gender == 'M'")
df[df["Gender"]=='M']
# Out:
# filtering data where Gender == 'M'
#     Emp ID Name Prefix   First Name Middle Initial   Last Name Gender  \
# 2   428945         Dr.          Joe              W    Robinson      M
# 4   193819         Mr.     Benjamin              R     Russell      M
# 5   499687         Mr.      Patrick              F      Bailey      M
# 10  231469         Mr.        Ralph              L      Flores      M
# 11  153989       Prof.         Jack              C   Alexander      M
# 13  301576        Hon.        Wayne              G      Watson      M
# 16  912990         Mr.       Joshua              T     Stewart      M
# 19  622406         Mr.       Thomas              Q       Lewis      M
# 21  969580       Prof.      Matthew              L      Turner      M
# 26  263480        Hon.       Daniel              K      Cooper      M
# 27  683826         Mr.        Roger              L     Roberts      M
# 32  621833         Mr.      Gregory              X     Edwards      M
# ...

# %%
## To perform statistical analysis of the data set
print("describe command will print the full analysis of the data set, present in the data frame")
df.describe
# Out:
# describe command will print the full analysis of the data set, present in the data frame
# <bound method NDFrame.describe of     Emp ID Name Prefix First Name Middle Initial   Last Name Gender  \
# 0   677509        Drs.       Lois              H      Walker      F
# 1   940761         Ms.     Brenda              S    Robinson      F
# 2   428945         Dr.        Joe              W    Robinson      M
# 3   408351        Drs.      Diane              I       Evans      F
# 4   193819         Mr.   Benjamin              R     Russell      M
# 5   499687         Mr.    Patrick              F      Bailey      M
# 6   539712         Ms.      Nancy              T       Baker      F
# 7   380086        Mrs.      Carol              V      Murphy      F
# 8   477616        Hon.    Frances              B       Young      F
# 9   162402        Hon.      Diana              T    Peterson      F
# 10  231469         Mr.      Ralph              L      Flores      M
# ...

# %%
## To print specific no of rows
df[0:10]
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 1  940761         Ms.     Brenda              S  Robinson      F
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
# 5  499687         Mr.    Patrick              F    Bailey      M
# 6  539712         Ms.      Nancy              T     Baker      F
# 7  380086        Mrs.      Carol              V    Murphy      F
# 8  477616        Hon.    Frances              B     Young      F
# 9  162402        Hon.      Diana              T  Peterson      F
#
#                          E Mail      Father's Name       Mother's Name  \
# 1     brenda.robinson@gmail.com   Raymond Robinson       Judy Robinson
# 2        joe.robinson@gmail.com     Scott Robinson  Stephanie Robinson
# 3         diane.evans@yahoo.com        Jason Evans      Michelle Evans
# ...

# %%
## To print all the rows
df[:]
# Out:
#     Emp ID Name Prefix First Name Middle Initial   Last Name Gender  \
# 0   677509        Drs.       Lois              H      Walker      F
# 1   940761         Ms.     Brenda              S    Robinson      F
# 2   428945         Dr.        Joe              W    Robinson      M
# 3   408351        Drs.      Diane              I       Evans      F
# 4   193819         Mr.   Benjamin              R     Russell      M
# 5   499687         Mr.    Patrick              F      Bailey      M
# 6   539712         Ms.      Nancy              T       Baker      F
# 7   380086        Mrs.      Carol              V      Murphy      F
# 8   477616        Hon.    Frances              B       Young      F
# 9   162402        Hon.      Diana              T    Peterson      F
# 10  231469         Mr.      Ralph              L      Flores      M
# 11  153989       Prof.       Jack              C   Alexander      M
# 12  386158        Mrs.    Melissa              Q        King      F
# ...

# %%
## To print data from specific columns
df[['Emp ID','Name Prefix','First Name','Middle Initial','Last Name','Gender']]
# Out:
#     Emp ID Name Prefix First Name Middle Initial   Last Name Gender
# 0   677509        Drs.       Lois              H      Walker      F
# 1   940761         Ms.     Brenda              S    Robinson      F
# 2   428945         Dr.        Joe              W    Robinson      M
# 3   408351        Drs.      Diane              I       Evans      F
# 4   193819         Mr.   Benjamin              R     Russell      M
# 5   499687         Mr.    Patrick              F      Bailey      M
# 6   539712         Ms.      Nancy              T       Baker      F
# 7   380086        Mrs.      Carol              V      Murphy      F
# 8   477616        Hon.    Frances              B       Young      F
# 9   162402        Hon.      Diana              T    Peterson      F
# 10  231469         Mr.      Ralph              L      Flores      M
# 11  153989       Prof.       Jack              C   Alexander      M
# 12  386158        Mrs.    Melissa              Q        King      F
# ...

# %%
## To print data from specific columns based on specific condition
df[['Emp ID','Name Prefix','First Name','Middle Initial','Last Name','Gender']][df['Gender']=='M']
# Out:
#     Emp ID Name Prefix   First Name Middle Initial   Last Name Gender
# 2   428945         Dr.          Joe              W    Robinson      M
# 4   193819         Mr.     Benjamin              R     Russell      M
# 5   499687         Mr.      Patrick              F      Bailey      M
# 10  231469         Mr.        Ralph              L      Flores      M
# 11  153989       Prof.         Jack              C   Alexander      M
# 13  301576        Hon.        Wayne              G      Watson      M
# 16  912990         Mr.       Joshua              T     Stewart      M
# 19  622406         Mr.       Thomas              Q       Lewis      M
# 21  969580       Prof.      Matthew              L      Turner      M
# 26  263480        Hon.       Daniel              K      Cooper      M
# 27  683826         Mr.        Roger              L     Roberts      M
# 32  621833         Mr.      Gregory              X     Edwards      M
# ...

# %%
## To print data from specific columns based on specific condition
df[['Emp ID','Name Prefix','First Name','Middle Initial','Last Name','Gender']][df['Gender']=='F']
# Out:
#     Emp ID Name Prefix First Name Middle Initial   Last Name Gender
# 0   677509        Drs.       Lois              H      Walker      F
# 1   940761         Ms.     Brenda              S    Robinson      F
# 3   408351        Drs.      Diane              I       Evans      F
# 6   539712         Ms.      Nancy              T       Baker      F
# 7   380086        Mrs.      Carol              V      Murphy      F
# 8   477616        Hon.    Frances              B       Young      F
# 9   162402        Hon.      Diana              T    Peterson      F
# 12  386158        Mrs.    Melissa              Q        King      F
# 14  441771        Mrs.     Cheryl              O       Scott      F
# 15  528509        Hon.      Paula              G        Diaz      F
# 17  214352         Ms.    Theresa              G         Lee      F
# 18  890290        Hon.      Julia              S       Scott      F
# 20  979607         Ms.      Carol              J     Edwards      F
# ...

# %%
## To print data from specific columns where Emp ID = max(Emp ID)
df[['Emp ID','Name Prefix','First Name','Middle Initial','Last Name','Gender']][df['Emp ID']==df['Emp ID'].max()]
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender
# 20  979607         Ms.      Carol              J   Edwards      F

# %%
## To print data from specific columns where Emp ID = min(Emp ID)
df[['Emp ID','Name Prefix','First Name','Middle Initial','Last Name','Gender']][df['Emp ID']==df['Emp ID'].min()]
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender
# 37  134841         Ms.      Donna              R     Brown      F

# %%
## To check the default index of the data set
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
## Modify the index to set it on SSN
df.set_index('SSN',inplace=True)
df
# Out:
#             Name Prefix First Name Middle Initial   Last Name Gender  \
# SSN
# 467-99-4677        Drs.       Lois              H      Walker      F
# 537-71-4566         Ms.     Brenda              S    Robinson      F
# 025-92-3584         Dr.        Joe              W    Robinson      M
# 314-35-9851        Drs.      Diane              I       Evans      F
# 121-98-7248         Mr.   Benjamin              R     Russell      M
# 439-99-7721         Mr.    Patrick              F      Bailey      M
# 641-29-2071         Ms.      Nancy              T       Baker      F
# 423-67-7023        Mrs.      Carol              V      Murphy      F
# 028-92-8912        Hon.    Frances              B       Young      F
# 512-33-6767        Hon.      Diana              T    Peterson      F
# 302-15-0130         Mr.      Ralph              L      Flores      M
# 428-99-9413       Prof.       Jack              C   Alexander      M
# ...

# %%
## To check the new index
df.index
# Out:
# Index(['467-99-4677', '537-71-4566', '025-92-3584', '314-35-9851',
#        '121-98-7248', '439-99-7721', '641-29-2071', '423-67-7023',
#        '028-92-8912', '512-33-6767', '302-15-0130', '428-99-9413',
#        '277-17-9106', '011-94-6649', '596-94-2279', '234-57-7671',
#        '755-07-3676', '055-02-9969', '251-99-1941', '467-99-2604',
#        '316-35-9870', '598-92-1988', '429-99-6443', '236-55-0172',
#        '730-28-1350', '456-99-5619', '181-86-2024', '120-98-6493',
#        '447-27-3175', '282-15-6434', '249-99-8821', '686-24-2843',
#        '010-94-6817', '358-08-7660', '013-94-5886', '198-84-0652',
#        '491-29-5152', '544-81-5182', '544-81-6171', '695-16-6506',
#        '491-29-7461', '311-35-2540', '047-15-1537', '399-31-7149',
#        '660-24-4434', '224-99-5928', '672-48-7749', '534-71-4481',
#        '681-24-3165', '459-99-9201', '207-84-9482', '027-92-0557',
#        '029-92-2155', '039-74-8867', '372-37-5315', '064-02-2589',
# ...

# %%
## Filtering the data based on the index value
df.loc['025-92-3584']
# Out:
# Name Prefix                                  Dr.
# First Name                                   Joe
# Middle Initial                                 W
# Last Name                               Robinson
# Gender                                         M
# E Mail                    joe.robinson@gmail.com
# Father's Name                     Scott Robinson
# Mother's Name                 Stephanie Robinson
# Mother's Maiden Name                      Taylor
# Date of Birth                          6/16/1963
# Time of Birth                        10:45:36 AM
# Age in Yrs.                                54.15
# Weight in Kgs.                                68
# Date of Joining                         8/3/2016
# Quarter of Joining                            Q3
# Half of Joining                               H2
# Year of Joining                             2016
# Month of Joining                               8
# Month Name of Joining                     August
# ...

# %%
## Reseting the index to default
df.reset_index(inplace=True)
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
## Modifying the index to set it on 'Emp ID'
df.set_index('Emp ID', inplace=True)

## It's throwing error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Emp ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-4402138685b2> in <module>()
#       1 ## Modifying the index to set it on 'Emp ID'
# ...

# %%
## Checking the index on 'E Mail'
df.set_index('E Mail',inplace=True)
df.index
# Out:
# Index(['lois.walker@hotmail.com', 'brenda.robinson@gmail.com',
#        'joe.robinson@gmail.com', 'diane.evans@yahoo.com',
#        'benjamin.russell@charter.net', 'patrick.bailey@aol.com',
#        'nancy.baker@bp.com', 'carol.murphy@gmail.com',
#        'frances.young@gmail.com', 'diana.peterson@hotmail.co.uk',
#        'ralph.flores@yahoo.com', 'jack.alexander@gmail.com',
#        'melissa.king@comcast.net', 'wayne.watson@gmail.com',
#        'cheryl.scott@gmail.com', 'paula.diaz@gmail.com',
#        'joshua.stewart@yahoo.ca', 'theresa.lee@gmail.com',
#        'julia.scott@apple.com', 'thomas.lewis@gmail.com',
#        'carol.edwards@msn.com', 'matthew.turner@gmail.com',
#        'joan.stewart@yahoo.com', 'ruby.rogers@gmail.com',
#        'carolyn.hayes@hotmail.co.uk', 'anne.russell@ibm.com',
#        'daniel.cooper@yahoo.com', 'roger.roberts@gmail.com',
#        'maria.walker@microsoft.com', 'brenda.butler@gmail.com',
#        'lillian.brown@aol.com', 'amy.howard@aol.com',
# ...

# %%
## Checking data based on new index value
df.index
# Out:
# Index(['lois.walker@hotmail.com', 'brenda.robinson@gmail.com',
#        'joe.robinson@gmail.com', 'diane.evans@yahoo.com',
#        'benjamin.russell@charter.net', 'patrick.bailey@aol.com',
#        'nancy.baker@bp.com', 'carol.murphy@gmail.com',
#        'frances.young@gmail.com', 'diana.peterson@hotmail.co.uk',
#        'ralph.flores@yahoo.com', 'jack.alexander@gmail.com',
#        'melissa.king@comcast.net', 'wayne.watson@gmail.com',
#        'cheryl.scott@gmail.com', 'paula.diaz@gmail.com',
#        'joshua.stewart@yahoo.ca', 'theresa.lee@gmail.com',
#        'julia.scott@apple.com', 'thomas.lewis@gmail.com',
#        'carol.edwards@msn.com', 'matthew.turner@gmail.com',
#        'joan.stewart@yahoo.com', 'ruby.rogers@gmail.com',
#        'carolyn.hayes@hotmail.co.uk', 'anne.russell@ibm.com',
#        'daniel.cooper@yahoo.com', 'roger.roberts@gmail.com',
#        'maria.walker@microsoft.com', 'brenda.butler@gmail.com',
#        'lillian.brown@aol.com', 'amy.howard@aol.com',
# ...

# %%
df.reset_index(inplace=True)
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
## Pending checks --> index didn't work out when tried to create on 'Emp ID', 'E Mail'
print("## Pending checks --> index didn't work out when tried to create on 'Emp ID', 'E Mail'")
# Out:
# ## Pending checks --> index didn't work out when tried to create on 'Emp ID', 'E Mail'
